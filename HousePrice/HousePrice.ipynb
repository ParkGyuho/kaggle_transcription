# %% [markdown]
# ### 모듈 불러오기

# %% [markdown]
# 이 친구가 왜 어려울까
# 1. 변수 81개 -> 수치형, 범주형 이딴게 너무 많음 -> 결측치, unique 값
# 2. log변환 -> SalePrice의 이상치, skew가 조금 쏠려있음
#
# Benz -> 비슷한 분류 -> columns 개많음, 결측치도 많음
#
# 어떻게 핸들링 해야될지 모름
# ------------------
# 한국 집과 다르기 때문 -> 마당, 지하실, 차고 -> 아파트(?!)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as stats
import matplotlib as mpl
import matplotlib.font_manager as fm

# %%
pd.options.display.max_columns = None
mpl.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### 파일 불러오기

# %%
train = pd.read_csv('./data/train.csv', index_col='Id')
train.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 2          Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 3          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 4          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 5          Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# ...

# %%
test = pd.read_csv('./data/test.csv',index_col='Id')
test.head()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1461         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1462         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 1463         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1464         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1465         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# ...

# %%
df = pd.concat([train, test])
df.shape
# Out:
# (2919, 80)

# %% [markdown]
# #### 기술통계 살펴보기

# %%
display(len(train.columns))
train.columns
# Out:
# 80
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
train.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315
# std      30.202904     20.645407   181.066207   456.098091   161.319273
# ...

# %%
train.describe(include='object')
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# count       1460         1460       1460       1460     1460       1460
# unique         3           25          9          8        5          8
# top          Gtl        NAmes       Norm       Norm     1Fam     1Story
# freq        1382          225       1260       1445     1220        726
#
#        RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType ExterQual  \
# count       1460     1460        1460        1460       1452      1460
# unique         6        8          15          16          4         4
# ...

# %% [markdown]
# ### 예측값인 SalePrice 살펴보기

# %%
train['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
sns.boxplot(data=train, y='SalePrice')
# Out:
# <AxesSubplot:ylabel='SalePrice'>

# %%
sns.histplot(train['SalePrice'])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %%
#왜도는 양수이면 왼쪽에 쳐짐, 음수면 오른쪽에 쳐짐
print('왜도:',train['SalePrice'].skew())
#첨도는 양수면 뾰족, 음수면 완만..
print('첨도:',train['SalePrice'].kurt())
# Out:
# 왜도: 1.8828757597682129
# 첨도: 6.536281860064529

# %%
train['SalePrice_log1p'] = np.log1p(train['SalePrice'])

# %%
train[['SalePrice','SalePrice_log1p']].hist(figsize=(15,4), bins=50)
plt.show()

# %%
stats.probplot(train['SalePrice'],plot=plt)
# Out:
# ((array([-3.30513952, -3.04793228, -2.90489705, ...,  2.90489705,
#           3.04793228,  3.30513952]),
#   array([ 34900,  35311,  37900, ..., 625000, 745000, 755000], dtype=int64)),
#  (74160.16474519414, 180921.19589041095, 0.9319665641512989))

# %%
stats.probplot(train['SalePrice_log1p'], plot=plt)
# Out:
# ((array([-3.30513952, -3.04793228, -2.90489705, ...,  2.90489705,
#           3.04793228,  3.30513952]),
#   array([10.46027076, 10.47197813, 10.54273278, ..., 13.34550853,
#          13.52114084, 13.53447435])),
#  (0.3982596466541508, 12.024057394918403, 0.9953761551826702))

# %% [markdown]
# ### 결측치 탐색

# %%
sns.heatmap(train.isnull())
# Out:
# <AxesSubplot:ylabel='Id'>

# %%
len(train)
# Out:
# 1460

# %%
((train.isnull().sum()/len(train))*100).sort_values(
    ascending=False).head(10)
# Out:
# PoolQC          99.520548
# MiscFeature     96.301370
# Alley           93.767123
# Fence           80.753425
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageYrBlt      5.547945
# GarageQual       5.547945
# GarageFinish     5.547945
# GarageCond       5.547945
# dtype: float64

# %% [markdown]
# ### 희소값 탐색

# %%
train.select_dtypes(include=object).nunique().sort_values(ascending=False)
# Out:
# Neighborhood     25
# Exterior2nd      16
# Exterior1st      15
# SaleType          9
# Condition1        9
# Condition2        8
# HouseStyle        8
# RoofMatl          8
# Functional        7
# BsmtFinType2      6
# Heating           6
# RoofStyle         6
# SaleCondition     6
# BsmtFinType1      6
# GarageType        6
# Foundation        6
# Electrical        5
# FireplaceQu       5
# HeatingQC         5
# GarageQual        5
# GarageCond        5
# MSZoning          5
# LotConfig         5
# ExterCond         5
# BldgType          5
# BsmtExposure      4
# MiscFeature       4
# Fence             4
# LotShape          4
# LandContour       4
# BsmtCond          4
# KitchenQual       4
# MasVnrType        4
# ExterQual         4
# BsmtQual          4
# LandSlope         3
# GarageFinish      3
# PavedDrive        3
# PoolQC            3
# Utilities         2
# CentralAir        2
# Street            2
# Alley             2
# dtype: int64

# %%
train['Neighborhood'].value_counts()
# Out:
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# StoneBr     25
# SWISU       25
# MeadowV     17
# Blmngtn     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: Neighborhood, dtype: int64

# %% [markdown]
# ### 상관관계 탐색

# %%
corr = df.corr()

# %%
corr['SalePrice'].sort_values(ascending=False).head(10)
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# Name: SalePrice, dtype: float64

# %%
#TotalBsmtSF -> 지하실의 총 평방미터
#1stFlrSF -> 1층 총 평방미터
#2ndFlrSF -> 2층 총 평방미터
#TotalSF -> 집 전체의 총 평방미터
df['TotalSF'] = df['TotalBsmtSF'] + df['1stFlrSF'] + df['2ndFlrSF']

# %%
df['TotalSF'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
# Garage(차고) 관련 범주형 변수 'None' 으로 결측치 대체
Garage_None = ['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']
df[Garage_None] = df[Garage_None].fillna('None')
df[Garage_None]
# Out:
#      GarageType GarageFinish GarageQual GarageCond
# Id
# 1        Attchd          RFn         TA         TA
# 2        Attchd          RFn         TA         TA
# 3        Attchd          RFn         TA         TA
# 4        Detchd          Unf         TA         TA
# 5        Attchd          RFn         TA         TA
# ...         ...          ...        ...        ...
# 2915       None         None       None       None
# 2916    CarPort          Unf         TA         TA
# 2917     Detchd          Unf         TA         TA
# 2918       None         None       None       None
# 2919     Attchd          Fin         TA         TA
#
# [2919 rows x 4 columns]

# %%
# Garage(차고) 관련 수치형 변수 0 으로 결측치 대체
Garage_0 = ['GarageYrBlt', 'GarageArea', 'GarageCars']
df[Garage_0] = df[Garage_0].fillna(0)

# %%
# Basement(지하실) 관련 수치형 변수 0 으로 결측치 대체
Basement_0 = ['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
              'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath']
df[Basement_0] = df[Basement_0].fillna(0)

# %%
# Basement(지하실) 관련 범주형 변수 'None' 으로 결측치 대체
Basement_None = ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']
df[Basement_None] = df[Basement_None].fillna('None')
